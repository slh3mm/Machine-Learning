# %% [markdown]
# # Assignment 4: Benchmarking Neural Nets with the XOR Problem

# %% [markdown]
# ### CS 4774 Machine Learning - Department of Computer Science - University of Virginia
# In this assignment, you will implement your own neural networks to classify non-linear data from the XOR dataset. For references, you may refer to my [lecture 13](https://docs.google.com/presentation/d/1otQfmMomWctLZKI3hHKAA4lLkbXFtagLaQov8gNh4LI/edit?usp=sharing) and [Colab Notebook 10](https://colab.research.google.com/drive/1x5biI3dP5YvvDEI0wapJcSgQNnATDzNe) if you need additional sample codes to help with your assignment. For deliverables, you must write code in Python/Tensorflow and submit **this** Jupyter Notebook file (.ipynb) to earn a total of 100 pts. Note that you must save your Notebook filename under this format: **yourUvaUserId_assignment_4_ann.ipynb**.

# %%
# You might want to use the following packages
import sklearn
from sklearn.datasets import make_moons
from sklearn.model_selection import train_test_split

import numpy as np
np.random.seed(42)

import matplotlib.pyplot as plt

# %% [markdown]
# ---
# ## 1. THE DATASET AND VISUALIZATION
#
# We will use the non-linear toy data called the XOR dataset. You may use the code snippet below to generate the train/validate/test set. Feel free to change the number of samples, and noise level. To keep the ratio between the sets consistent, please do not change the test_size and random_state parameters.

# %%
def make_xor(n_points):
    centers = np.array([[0,0],[0,1],[1,0],[1,1]])
    labels = np.array([0,1,1,0])
    data = np.array([]).reshape(-1,3)
    for center, label in zip(centers,labels):
        points = np.random.normal(loc=center,scale=0.2,size=(n_points//4,2))
        points_labels = np.hstack((points,label*np.ones(n_points//4).reshape((-1, 1))))
        data = np.vstack((data,points_labels))
    return (data[:,[0,1]],data[:,2])


X, y = make_xor(1000)
y=y.astype(np.int64)
X_train_full, X_test, y_train_full, y_test = train_test_split(X, y, test_size=0.2, random_state=49)
X_train, X_val, y_train, y_val = train_test_split(X_train_full, y_train_full, test_size= 0.1, random_state=49) 
print(X_train.shape)
print(X_test.shape)
print(X_val.shape)
plt.scatter(X[:,0], X[:,1], s=40, c=y, cmap=plt.cm.Spectral)
# Out:
# (720, 2)
# (200, 2)
# (80, 2)

# %% [markdown]
# ---
# ## 2. TRAIN A SIMPLE ANN FOR CLASSIFICATION TASK
#
# Use the standard libarary of Neural Net on the training data, and then test the classifier on the test data. You will create a simple ANN with 3 layers: an Input Layer, a Hidden Layer and an Output Layer. For each layer, you can specify the number of nodes appropriate for the XOR problem. Also, feel free to tune the network as you see fit. You have to report the accuracy of the network on the validation set.

# %%
import tensorflow as tf
from tensorflow import keras
from keras import layers
from keras import activations

my_model = keras.Sequential()
# Your code here!
my_model.add(layers.Dense(50, activation='relu'))
my_model.add(layers.Dense(2, activation='softmax'))
my_model.compile(loss="sparse_categorical_crossentropy" ,
              optimizer="sgd",
              metrics=["accuracy"])
history = my_model.fit(X_train, y_train, batch_size=64, epochs=30,
                    validation_data=(X_test, y_test))
output = my_model.evaluate(X_test, y_test)
print(output)
# Out:
# Epoch 1/30
# 12/12 [==============================] - 1s 17ms/step - loss: 0.7120 - accuracy: 0.5708 - val_loss: 0.7069 - val_accuracy: 0.6150
# Epoch 2/30
# 12/12 [==============================] - 0s 6ms/step - loss: 0.6997 - accuracy: 0.6375 - val_loss: 0.6950 - val_accuracy: 0.6400
# Epoch 3/30
# 12/12 [==============================] - 0s 5ms/step - loss: 0.6879 - accuracy: 0.6972 - val_loss: 0.6870 - val_accuracy: 0.6850
# Epoch 4/30
# 12/12 [==============================] - 0s 5ms/step - loss: 0.6797 - accuracy: 0.7236 - val_loss: 0.6804 - val_accuracy: 0.7150
# Epoch 5/30
# 12/12 [==============================] - 0s 4ms/step - loss: 0.6728 - accuracy: 0.7319 - val_loss: 0.6741 - val_accuracy: 0.7200
# Epoch 6/30
# 12/12 [==============================] - 0s 5ms/step - loss: 0.6664 - accuracy: 0.7278 - val_loss: 0.6686 - val_accuracy: 0.7200
# Epoch 7/30
# 12/12 [==============================] - 0s 6ms/step - loss: 0.6606 - accuracy: 0.7292 - val_loss: 0.6639 - val_accuracy: 0.7200
# Epoch 8/30
# 12/12 [==============================] - 0s 5ms/step - loss: 0.6557 - accuracy: 0.7319 - val_loss: 0.6593 - val_accuracy: 0.7250
# Epoch 9/30
# 12/12 [==============================] - 0s 5ms/step - loss: 0.6508 - accuracy: 0.7333 - val_loss: 0.6551 - val_accuracy: 0.7300
# Epoch 10/30
# 12/12 [==============================] - 0s 4ms/step - loss: 0.6461 - accuracy: 0.7833 - val_loss: 0.6512 - val_accuracy: 0.7600
# Epoch 11/30
# 12/12 [==============================] - 0s 5ms/step - loss: 0.6421 - accuracy: 0.8556 - val_loss: 0.6474 - val_accuracy: 0.7900
# Epoch 12/30
# 12/12 [==============================] - 0s 6ms/step - loss: 0.6384 - accuracy: 0.8625 - val_loss: 0.6434 - val_accuracy: 0.8500
# Epoch 13/30
# 12/12 [==============================] - 0s 5ms/step - loss: 0.6347 - accuracy: 0.9208 - val_loss: 0.6400 - val_accuracy: 0.8950
# Epoch 14/30
# 12/12 [==============================] - 0s 5ms/step - loss: 0.6311 - accuracy: 0.9319 - val_loss: 0.6366 - val_accuracy: 0.9100
# Epoch 15/30
# 12/12 [==============================] - 0s 4ms/step - loss: 0.6278 - accuracy: 0.9375 - val_loss: 0.6334 - val_accuracy: 0.9250
# Epoch 16/30
# 12/12 [==============================] - 0s 4ms/step - loss: 0.6246 - accuracy: 0.9403 - val_loss: 0.6304 - val_accuracy: 0.9250
# Epoch 17/30
# 12/12 [==============================] - 0s 6ms/step - loss: 0.6216 - accuracy: 0.9403 - val_loss: 0.6274 - val_accuracy: 0.9350
# Epoch 18/30
# 12/12 [==============================] - 0s 5ms/step - loss: 0.6187 - accuracy: 0.9444 - val_loss: 0.6245 - val_accuracy: 0.9350
# Epoch 19/30
# 12/12 [==============================] - 0s 4ms/step - loss: 0.6158 - accuracy: 0.9458 - val_loss: 0.6214 - val_accuracy: 0.9400
# Epoch 20/30
# 12/12 [==============================] - 0s 5ms/step - loss: 0.6129 - accuracy: 0.9486 - val_loss: 0.6186 - val_accuracy: 0.9350
# Epoch 21/30
# 12/12 [==============================] - 0s 5ms/step - loss: 0.6101 - accuracy: 0.9486 - val_loss: 0.6156 - val_accuracy: 0.9350
# Epoch 22/30
# 12/12 [==============================] - 0s 6ms/step - loss: 0.6072 - accuracy: 0.9514 - val_loss: 0.6128 - val_accuracy: 0.9350
# Epoch 23/30
# 12/12 [==============================] - 0s 6ms/step - loss: 0.6045 - accuracy: 0.9500 - val_loss: 0.6101 - val_accuracy: 0.9350
# Epoch 24/30
# 12/12 [==============================] - 0s 6ms/step - loss: 0.6017 - accuracy: 0.9500 - val_loss: 0.6071 - val_accuracy: 0.9350
# Epoch 25/30
# 12/12 [==============================] - 0s 5ms/step - loss: 0.5989 - accuracy: 0.9514 - val_loss: 0.6041 - val_accuracy: 0.9400
# Epoch 26/30
# 12/12 [==============================] - 0s 5ms/step - loss: 0.5963 - accuracy: 0.9528 - val_loss: 0.6012 - val_accuracy: 0.9500
# Epoch 27/30
# 12/12 [==============================] - 0s 6ms/step - loss: 0.5934 - accuracy: 0.9528 - val_loss: 0.5984 - val_accuracy: 0.9400
# Epoch 28/30
# 12/12 [==============================] - 0s 5ms/step - loss: 0.5906 - accuracy: 0.9500 - val_loss: 0.5956 - val_accuracy: 0.9400
# Epoch 29/30
# 12/12 [==============================] - 0s 6ms/step - loss: 0.5878 - accuracy: 0.9486 - val_loss: 0.5929 - val_accuracy: 0.9400
# Epoch 30/30
# 12/12 [==============================] - 0s 5ms/step - loss: 0.5849 - accuracy: 0.9486 - val_loss: 0.5898 - val_accuracy: 0.9400
# 7/7 [==============================] - 0s 3ms/step - loss: 0.5898 - accuracy: 0.9400
# [0.5898458361625671, 0.9399999976158142]

# %% [markdown]
# - - -
# ## 3. IMPLEMENTING YOUR OWN SIMPLE NEURAL NETWORK
#
# Now that you see how the standard library ANN performs on the XOR dataset, you will attempt to implement your own version of the neural network. To help you, a template has been created including the backpropagation. Essensially, you will get the backward gradients for free. However, please note that the backprop implementation assume usage of tanh activation for the hidden layer and softmax for the output layer. There are some subtasks which you need to implement in order to get the network to work properly.

# %%
from sklearn.base import BaseEstimator
from sklearn.preprocessing import OneHotEncoder
from scipy import special

class MyNeuralNet(BaseEstimator):
    """Your implementation of a simple neural network"""
    def tanh(self, z):
      return np.tanh(z)

    def softmax(self, z):
      sum = 0
      for num in z:
        sum += np.exp(num)
      ans = np.exp(z)/sum
      return ans

    def avg_cross_entropy(self, y, p):
      cross_entropy = (-y * np.log(p)) - ((1-y)*(np.log(1-p)))
      avg_cross_entropy = np.sum(np.asarray(cross_entropy))/len(cross_entropy)
      return avg_cross_entropy
      
    def __init__ (self, n0, n1, n2, alpha=0.01):
        """
        @param: n0: Number of nodes in the input layer
        @param: n1: Number of nodes in the hidden layer
        @param: n2: Number of nodes in the output layer
        @param: alpha: The Learning Rate
        """

        # SUBTASK 1: Initialize the parameters to random values.
        np.random.seed(42)
        self.W1 = np.random.randn(n1, n0) 
        self.b1 = np.random.randn(n1,1)
        self.W2 = np.random.randn(n2, n1)
        self.b2 = np.random.randn(n2,1)
        # print(self.W1.shape)
        # print(self.b1.shape)
        # print(self.W2.shape)
        # print(self.b2.shape)

        # Configure the learning rate
        self.alpha = alpha
        # One-hot encoder for labels
        self.encoder = OneHotEncoder(sparse=False)
        
    def forward_pass(self, X):
        """
        Pass the signal forward through the layers.
        @param: X: feature
        @return: A1: saved value of the output of the hidden layer
        @return: A2: activated return value of the output layer.
        """
        # SUBTASK 2: Implement Forward propagation.
        # Note: that you must implement tanh activation for the hidden layer 
        # and softmax for the output layer
        
        Z1 = np.dot(self.W1,X) + self.b1
        A1 = self.tanh(Z1)
        Z2 = np.dot(self.W2,A1) + self.b2
        A2 = self.softmax(Z2)
        
        return A1, A2 


    def loss(self, X, y):
        """
        Evaluate the total loss on the dataset
        @param: X: features
        @param: y: labels
        @return: L: the loss value
        """
        
        # SUBTASK 3: Calculate the loss using Cross-Entropy
        # You will need to return the average loss on the data
        # Hint: Use A2 to calculate the loss
        A1, A2 = self.forward_pass(X)  
        # Another Hint: First, you may want to convert the lable y into a one-hot vector
        Y = self.one_hot(y)
        L = self.avg_cross_entropy(Y,A2) 
        return L

    def backward_pass(self, A1, A2, X, y):
        """
        @param: X: feature
        @param: y: label
        @param: A1: saved value of the output of the hidden layer
        @param: a2: activated return value of the output layer.

        @return: dW1: the loss gradient of W1
        @return: db1: the loss gradient of b1
        @return: dW2: the loss gradient of W2
        @return: db2: the loss gradient of b2
        """

        # You DO NOT CHANGE this function, ...
        # unless you are advanced and want to use different activation function for your forward pass
        # This is an elegant partial derivative of cross entropy with softmax
        # Ref document: https://deepnotes.io/softmax-crossentropy
        m   = y.shape[0]
        dZ2 = A2 - self.one_hot(y)
        dW2 = np.dot(dZ2, A1.T)/m
        db2 = np.sum(dZ2, axis=1, keepdims=True)/m
        dZ1 = np.multiply( np.dot( self.W2.T, dZ2), 1-np.power( A1, 2))
        dW1 = np.dot(dZ1, X.T)/m
        db1 = np.sum(dZ1, axis=1, keepdims=True)/m

        return dW1, db1, dW2, db2


    def fit(self, X, y , epochs, X_val, Y_val):
        """
        Learns parameters for the neural network and returns the model.
        
        @param: X: the training feature
        @param: y: the train label
        @param: epochs: Number of passes through the training data for gradient descent
        @param: X_val: the feature of validation set
        @param: y_val: the label of validation set
        """

        # Input checks: X and X_val needs to be in the form of n0 x m
        if (X.shape[0] > X.shape[1]): X = X.T
        if (X_val.shape[0] > X_val.shape[1]): X_val = X_val.T

        # Gradient descent
        for i in range(0, epochs):
            
            # SUBTASK 4: Compute the forward, backward, and gradient descent parameter update
            # Step 1: Forward pass
            A1, A2 = self.forward_pass(X)
            
            # Step 2: Backward pass
            dW1, db1, dW2, db2 = self.backward_pass(A1,A2,X,y)

            # Step 3: Gradient Descent 
            self.W1 = self.W1 - (self.alpha * dW1)
            self.b1 = self.b1 - (self.alpha * db1)
            self.W2 = self.W2 - (self.alpha * dW2)
            self.b2 = self.b2 - (self.alpha * db2)

            # Print the loss and validation accuracy every 10 epochs.
            if i % 10 == 0:
                print("Epoch %i/%i - loss: %f - accuracy: %f - val_loss: %f - val_accuracy: %f" 
                      %(i,epochs, self.loss(X, y), self.evaluate(X, y),
                        self.loss(X_val, y_val), self.evaluate(X_val,y_val)))

    def predict(self, X):
        """
        Predict label vector y
        """
        # check X for the form of n0 x m
        if (X.shape[0] > X.shape[1]): X = X.T
        
        # SUBTASK 5: Implement the prediction process. 
        # Hint: It should include a forward pass, and then use the class with higher probability.
        A1, A2 = self.forward_pass(X)
        m = len(A2[0])
        y_hat = np.zeros(m)
        for i in range(m):
          if(A2[0][i] <= A2[1][i]):
            y_hat[i] = 1
        return y_hat


    def evaluate(self, X, y):
        """
        Evaluate the accuracy of the model
        """
        m = y.shape[0]
        y_hat = self.predict(X)
        correct_y = (y_hat == y).astype(int)

        return sum(correct_y)/m


    def one_hot(self, y):
        """
        Utility function: Convert a label vector to one-hot vector
        """
        Y = self.encoder.fit_transform(y.reshape(len(y),1))  
        return Y.T # Transpose to get into same shape 1 x m


    def plot_decision_boundary(self, X, y):
        """
        Utility Function: Plot a decision boundary for visualization purpose.
        If you don't fully understand this function don't worry, it just generates the contour plot below.
        """
        # Set min and max values and give it some padding
        x_min, x_max = X[:,0].min() - .5, X[:,0].max() + .5
        y_min, y_max = X[:,1].min() - .5, X[:,1].max() + .5
        h = 0.01
        # Generate a grid of points with distance h between them
        xx, yy = np.meshgrid(np.arange(x_min, x_max, h), np.arange(y_min, y_max, h))
        # Predict the function value for the whole gid
        data_grid= np.c_[xx.ravel(), yy.ravel()]
        Z = self.predict(data_grid)
        Z = Z.reshape(xx.shape)

        # Plot the contour and training examples
        plt.contourf(xx, yy, Z, cmap=plt.cm.Pastel1)
        plt.scatter(X[:,0], X[:,1], c=y, cmap=plt.cm.Spectral)

# %% [markdown]
# ---
# ## 4. REFLECT ON THE COMPARISON BETWEEN YOUR IMPLEMENTATION TO THE STANDARD LIBRARY
# Now that you have implemented your own Neural Net class, let's use it! Create at least 3 instances of your Neural Net class, each with a different number of nodes in the hiden layer, tune it with the appropriate learning rate and number of iteration. You will test their performance in the Xor dataset and report the test accuracy metrics for each instance of your neural network.
#
# Based on the test accuracy, compare your models with the standard library version.

# %%
# MODEL 1 here
n0 = 2 # input layer dimensionality
n1 = 3 # hidden layer dimensionality
n2 = 2 # output layer dimensionality
alpha = .5 # learning rate for gradient descent
epochs = 500 # number of iteration/epochs

# Build a model with 3 layers
myModel1 = MyNeuralNet(n0, n1, n2, alpha);
myModel1.fit(X_train, y_train, epochs, X_val, y_val)
print("Accuracy on the test set is ", myModel1.evaluate(X_test, y_test))

# Plot the decision boundary
myModel1.plot_decision_boundary(X_train, y_train)
# Out:
# Epoch 0/500 - loss: 523.323553 - accuracy: 0.495833 - val_loss: 59.773775 - val_accuracy: 0.412500
# Epoch 10/500 - loss: 493.120944 - accuracy: 0.520833 - val_loss: 54.657766 - val_accuracy: 0.575000
# Epoch 20/500 - loss: 474.853289 - accuracy: 0.637500 - val_loss: 52.887428 - val_accuracy: 0.700000
# Epoch 30/500 - loss: 456.200757 - accuracy: 0.684722 - val_loss: 50.936107 - val_accuracy: 0.750000
# Epoch 40/500 - loss: 438.032209 - accuracy: 0.701389 - val_loss: 48.940197 - val_accuracy: 0.762500
# Epoch 50/500 - loss: 420.914532 - accuracy: 0.708333 - val_loss: 46.992400 - val_accuracy: 0.762500
# Epoch 60/500 - loss: 402.849156 - accuracy: 0.712500 - val_loss: 44.843011 - val_accuracy: 0.775000
# Epoch 70/500 - loss: 378.756460 - accuracy: 0.719444 - val_loss: 41.804336 - val_accuracy: 0.775000
# Epoch 80/500 - loss: 350.650654 - accuracy: 0.700000 - val_loss: 38.192153 - val_accuracy: 0.750000
# Epoch 90/500 - loss: 320.853553 - accuracy: 0.700000 - val_loss: 34.582276 - val_accuracy: 0.750000
# Epoch 100/500 - loss: 266.162918 - accuracy: 0.955556 - val_loss: 28.709512 - val_accuracy: 0.950000
# Epoch 110/500 - loss: 206.793008 - accuracy: 0.973611 - val_loss: 22.925365 - val_accuracy: 0.950000
# Epoch 120/500 - loss: 163.688216 - accuracy: 0.975000 - val_loss: 18.611697 - val_accuracy: 0.962500
# Epoch 130/500 - loss: 134.799824 - accuracy: 0.979167 - val_loss: 15.616950 - val_accuracy: 0.962500
# Epoch 140/500 - loss: 114.991117 - accuracy: 0.980556 - val_loss: 13.503308 - val_accuracy: 0.962500
# Epoch 150/500 - loss: 100.847858 - accuracy: 0.980556 - val_loss: 11.961612 - val_accuracy: 0.962500
# Epoch 160/500 - loss: 90.373163 - accuracy: 0.981944 - val_loss: 10.802275 - val_accuracy: 0.950000
# Epoch 170/500 - loss: 82.371352 - accuracy: 0.980556 - val_loss: 9.907019 - val_accuracy: 0.950000
# Epoch 180/500 - loss: 76.096141 - accuracy: 0.980556 - val_loss: 9.199665 - val_accuracy: 0.950000
# Epoch 190/500 - loss: 71.063614 - accuracy: 0.980556 - val_loss: 8.629659 - val_accuracy: 0.950000
# Epoch 200/500 - loss: 66.949381 - accuracy: 0.980556 - val_loss: 8.162517 - val_accuracy: 0.950000
# Epoch 210/500 - loss: 63.529561 - accuracy: 0.980556 - val_loss: 7.774101 - val_accuracy: 0.950000
# Epoch 220/500 - loss: 60.645618 - accuracy: 0.980556 - val_loss: 7.447114 - val_accuracy: 0.950000
# Epoch 230/500 - loss: 58.182697 - accuracy: 0.980556 - val_loss: 7.168893 - val_accuracy: 0.950000
# Epoch 240/500 - loss: 56.055875 - accuracy: 0.981944 - val_loss: 6.929981 - val_accuracy: 0.950000
# Epoch 250/500 - loss: 54.201209 - accuracy: 0.981944 - val_loss: 6.723187 - val_accuracy: 0.950000
# Epoch 260/500 - loss: 52.569751 - accuracy: 0.981944 - val_loss: 6.542959 - val_accuracy: 0.950000
# Epoch 270/500 - loss: 51.123476 - accuracy: 0.981944 - val_loss: 6.384941 - val_accuracy: 0.950000
# Epoch 280/500 - loss: 49.832443 - accuracy: 0.981944 - val_loss: 6.245673 - val_accuracy: 0.962500
# Epoch 290/500 - loss: 48.672784 - accuracy: 0.981944 - val_loss: 6.122372 - val_accuracy: 0.962500
# Epoch 300/500 - loss: 47.625259 - accuracy: 0.981944 - val_loss: 6.012775 - val_accuracy: 0.962500
# Epoch 310/500 - loss: 46.674199 - accuracy: 0.981944 - val_loss: 5.915020 - val_accuracy: 0.962500
# Epoch 320/500 - loss: 45.806718 - accuracy: 0.981944 - val_loss: 5.827566 - val_accuracy: 0.962500
# Epoch 330/500 - loss: 45.012133 - accuracy: 0.981944 - val_loss: 5.749121 - val_accuracy: 0.962500
# Epoch 340/500 - loss: 44.281506 - accuracy: 0.981944 - val_loss: 5.678596 - val_accuracy: 0.962500
# Epoch 350/500 - loss: 43.607311 - accuracy: 0.981944 - val_loss: 5.615069 - val_accuracy: 0.962500
# Epoch 360/500 - loss: 42.983162 - accuracy: 0.981944 - val_loss: 5.557747 - val_accuracy: 0.962500
# Epoch 370/500 - loss: 42.403607 - accuracy: 0.981944 - val_loss: 5.505953 - val_accuracy: 0.962500
# Epoch 380/500 - loss: 41.863962 - accuracy: 0.981944 - val_loss: 5.459096 - val_accuracy: 0.962500
# Epoch 390/500 - loss: 41.360182 - accuracy: 0.981944 - val_loss: 5.416668 - val_accuracy: 0.962500
# Epoch 400/500 - loss: 40.888754 - accuracy: 0.981944 - val_loss: 5.378220 - val_accuracy: 0.962500
# Epoch 410/500 - loss: 40.446611 - accuracy: 0.981944 - val_loss: 5.343362 - val_accuracy: 0.962500
# Epoch 420/500 - loss: 40.031066 - accuracy: 0.981944 - val_loss: 5.311747 - val_accuracy: 0.975000
# Epoch 430/500 - loss: 39.639753 - accuracy: 0.981944 - val_loss: 5.283071 - val_accuracy: 0.975000
# Epoch 440/500 - loss: 39.270580 - accuracy: 0.981944 - val_loss: 5.257063 - val_accuracy: 0.975000
# Epoch 450/500 - loss: 38.921693 - accuracy: 0.981944 - val_loss: 5.233481 - val_accuracy: 0.975000
# Epoch 460/500 - loss: 38.591436 - accuracy: 0.981944 - val_loss: 5.212111 - val_accuracy: 0.975000
# Epoch 470/500 - loss: 38.278336 - accuracy: 0.981944 - val_loss: 5.192758 - val_accuracy: 0.975000
# Epoch 480/500 - loss: 37.981067 - accuracy: 0.983333 - val_loss: 5.175251 - val_accuracy: 0.975000
# Epoch 490/500 - loss: 37.698441 - accuracy: 0.983333 - val_loss: 5.159433 - val_accuracy: 0.975000
# Accuracy on the test set is  0.96

# %%
# MODEL 2 here
n0 = 2 # input layer dimensionality
n1 = 8 # hidden layer dimensionality
n2 = 2 # output layer dimensionality
alpha = .08 # learning rate for gradient descent
epochs = 500 # number of iteration/epochs

# Build a model with 3 layers
myModel1 = MyNeuralNet(n0, n1, n2, alpha);
myModel1.fit(X_train, y_train, epochs, X_val, y_val)
print("Accuracy on the test set is ", myModel1.evaluate(X_test, y_test))

# Plot the decision boundary
myModel1.plot_decision_boundary(X_train, y_train)
# Out:
# Epoch 0/500 - loss: 558.466691 - accuracy: 0.529167 - val_loss: 63.031538 - val_accuracy: 0.512500
# Epoch 10/500 - loss: 486.441440 - accuracy: 0.529167 - val_loss: 56.588593 - val_accuracy: 0.512500
# Epoch 20/500 - loss: 448.921211 - accuracy: 0.623611 - val_loss: 52.056336 - val_accuracy: 0.537500
# Epoch 30/500 - loss: 424.830290 - accuracy: 0.759722 - val_loss: 49.039745 - val_accuracy: 0.700000
# Epoch 40/500 - loss: 406.238601 - accuracy: 0.830556 - val_loss: 46.758391 - val_accuracy: 0.812500
# Epoch 50/500 - loss: 390.058248 - accuracy: 0.877778 - val_loss: 44.841000 - val_accuracy: 0.875000
# Epoch 60/500 - loss: 375.141571 - accuracy: 0.901389 - val_loss: 43.130505 - val_accuracy: 0.887500
# Epoch 70/500 - loss: 361.052656 - accuracy: 0.922222 - val_loss: 41.556681 - val_accuracy: 0.900000
# Epoch 80/500 - loss: 347.610120 - accuracy: 0.933333 - val_loss: 40.084366 - val_accuracy: 0.900000
# Epoch 90/500 - loss: 334.727280 - accuracy: 0.936111 - val_loss: 38.693760 - val_accuracy: 0.912500
# Epoch 100/500 - loss: 322.357413 - accuracy: 0.937500 - val_loss: 37.372766 - val_accuracy: 0.912500
# Epoch 110/500 - loss: 310.473854 - accuracy: 0.938889 - val_loss: 36.113686 - val_accuracy: 0.925000
# Epoch 120/500 - loss: 299.061265 - accuracy: 0.940278 - val_loss: 34.911527 - val_accuracy: 0.925000
# Epoch 130/500 - loss: 288.110729 - accuracy: 0.941667 - val_loss: 33.763003 - val_accuracy: 0.925000
# Epoch 140/500 - loss: 277.616508 - accuracy: 0.945833 - val_loss: 32.665862 - val_accuracy: 0.925000
# Epoch 150/500 - loss: 267.573842 - accuracy: 0.948611 - val_loss: 31.618447 - val_accuracy: 0.925000
# Epoch 160/500 - loss: 257.977500 - accuracy: 0.948611 - val_loss: 30.619393 - val_accuracy: 0.925000
# Epoch 170/500 - loss: 248.820927 - accuracy: 0.948611 - val_loss: 29.667439 - val_accuracy: 0.925000
# Epoch 180/500 - loss: 240.095826 - accuracy: 0.950000 - val_loss: 28.761316 - val_accuracy: 0.925000
# Epoch 190/500 - loss: 231.792054 - accuracy: 0.951389 - val_loss: 27.899685 - val_accuracy: 0.925000
# Epoch 200/500 - loss: 223.897724 - accuracy: 0.951389 - val_loss: 27.081111 - val_accuracy: 0.925000
# Epoch 210/500 - loss: 216.399426 - accuracy: 0.951389 - val_loss: 26.304067 - val_accuracy: 0.937500
# Epoch 220/500 - loss: 209.282521 - accuracy: 0.951389 - val_loss: 25.566939 - val_accuracy: 0.937500
# Epoch 230/500 - loss: 202.531451 - accuracy: 0.951389 - val_loss: 24.868053 - val_accuracy: 0.937500
# Epoch 240/500 - loss: 196.130041 - accuracy: 0.952778 - val_loss: 24.205692 - val_accuracy: 0.937500
# Epoch 250/500 - loss: 190.061782 - accuracy: 0.952778 - val_loss: 23.578117 - val_accuracy: 0.937500
# Epoch 260/500 - loss: 184.310073 - accuracy: 0.954167 - val_loss: 22.983594 - val_accuracy: 0.937500
# Epoch 270/500 - loss: 178.858429 - accuracy: 0.954167 - val_loss: 22.420407 - val_accuracy: 0.937500
# Epoch 280/500 - loss: 173.690655 - accuracy: 0.954167 - val_loss: 21.886872 - val_accuracy: 0.937500
# Epoch 290/500 - loss: 168.790974 - accuracy: 0.959722 - val_loss: 21.381353 - val_accuracy: 0.937500
# Epoch 300/500 - loss: 164.144134 - accuracy: 0.961111 - val_loss: 20.902271 - val_accuracy: 0.937500
# Epoch 310/500 - loss: 159.735479 - accuracy: 0.961111 - val_loss: 20.448105 - val_accuracy: 0.937500
# Epoch 320/500 - loss: 155.550999 - accuracy: 0.961111 - val_loss: 20.017404 - val_accuracy: 0.937500
# Epoch 330/500 - loss: 151.577363 - accuracy: 0.961111 - val_loss: 19.608786 - val_accuracy: 0.937500
# Epoch 340/500 - loss: 147.801927 - accuracy: 0.962500 - val_loss: 19.220938 - val_accuracy: 0.937500
# Epoch 350/500 - loss: 144.212743 - accuracy: 0.962500 - val_loss: 18.852620 - val_accuracy: 0.937500
# Epoch 360/500 - loss: 140.798542 - accuracy: 0.961111 - val_loss: 18.502659 - val_accuracy: 0.937500
# Epoch 370/500 - loss: 137.548727 - accuracy: 0.962500 - val_loss: 18.169953 - val_accuracy: 0.937500
# Epoch 380/500 - loss: 134.453339 - accuracy: 0.963889 - val_loss: 17.853463 - val_accuracy: 0.937500
# Epoch 390/500 - loss: 131.503044 - accuracy: 0.963889 - val_loss: 17.552214 - val_accuracy: 0.937500
# Epoch 400/500 - loss: 128.689096 - accuracy: 0.963889 - val_loss: 17.265293 - val_accuracy: 0.937500
# Epoch 410/500 - loss: 126.003308 - accuracy: 0.963889 - val_loss: 16.991842 - val_accuracy: 0.937500
# Epoch 420/500 - loss: 123.438027 - accuracy: 0.965278 - val_loss: 16.731058 - val_accuracy: 0.937500
# Epoch 430/500 - loss: 120.986096 - accuracy: 0.965278 - val_loss: 16.482191 - val_accuracy: 0.937500
# Epoch 440/500 - loss: 118.640830 - accuracy: 0.965278 - val_loss: 16.244536 - val_accuracy: 0.937500
# Epoch 450/500 - loss: 116.395982 - accuracy: 0.965278 - val_loss: 16.017436 - val_accuracy: 0.937500
# Epoch 460/500 - loss: 114.245718 - accuracy: 0.966667 - val_loss: 15.800274 - val_accuracy: 0.937500
# Epoch 470/500 - loss: 112.184586 - accuracy: 0.966667 - val_loss: 15.592475 - val_accuracy: 0.950000
# Epoch 480/500 - loss: 110.207496 - accuracy: 0.968056 - val_loss: 15.393499 - val_accuracy: 0.937500
# Epoch 490/500 - loss: 108.309690 - accuracy: 0.968056 - val_loss: 15.202842 - val_accuracy: 0.937500
# Accuracy on the test set is  0.955

# %%
# MODEL 3 here
n0 = 2 # input layer dimensionality
n1 = 2 # hidden layer dimensionality
n2 = 2 # output layer dimensionality
alpha = .01 # learning rate for gradient descent
epochs = 500 # number of iteration/epochs

# Build a model with 3 layers
myModel1 = MyNeuralNet(n0, n1, n2, alpha);
myModel1.fit(X_train, y_train, epochs, X_val, y_val)
print("Accuracy on the test set is ", myModel1.evaluate(X_test, y_test))

# Plot the decision boundary
myModel1.plot_decision_boundary(X_train, y_train)
# Out:
# Epoch 0/500 - loss: 533.935542 - accuracy: 0.505556 - val_loss: 61.219511 - val_accuracy: 0.487500
# Epoch 10/500 - loss: 531.780496 - accuracy: 0.506944 - val_loss: 60.965474 - val_accuracy: 0.487500
# Epoch 20/500 - loss: 529.721948 - accuracy: 0.506944 - val_loss: 60.725565 - val_accuracy: 0.487500
# Epoch 30/500 - loss: 527.754213 - accuracy: 0.506944 - val_loss: 60.498450 - val_accuracy: 0.487500
# Epoch 40/500 - loss: 525.872071 - accuracy: 0.509722 - val_loss: 60.282975 - val_accuracy: 0.487500
# Epoch 50/500 - loss: 524.070684 - accuracy: 0.511111 - val_loss: 60.078137 - val_accuracy: 0.487500
# Epoch 60/500 - loss: 522.345539 - accuracy: 0.511111 - val_loss: 59.883054 - val_accuracy: 0.487500
# Epoch 70/500 - loss: 520.692405 - accuracy: 0.509722 - val_loss: 59.696947 - val_accuracy: 0.487500
# Epoch 80/500 - loss: 519.107298 - accuracy: 0.508333 - val_loss: 59.519123 - val_accuracy: 0.487500
# Epoch 90/500 - loss: 517.586462 - accuracy: 0.508333 - val_loss: 59.348966 - val_accuracy: 0.487500
# Epoch 100/500 - loss: 516.126344 - accuracy: 0.508333 - val_loss: 59.185919 - val_accuracy: 0.487500
# Epoch 110/500 - loss: 514.723578 - accuracy: 0.508333 - val_loss: 59.029478 - val_accuracy: 0.487500
# Epoch 120/500 - loss: 513.374980 - accuracy: 0.511111 - val_loss: 58.879188 - val_accuracy: 0.487500
# Epoch 130/500 - loss: 512.077524 - accuracy: 0.509722 - val_loss: 58.734631 - val_accuracy: 0.487500
# Epoch 140/500 - loss: 510.828344 - accuracy: 0.509722 - val_loss: 58.595424 - val_accuracy: 0.487500
# Epoch 150/500 - loss: 509.624717 - accuracy: 0.511111 - val_loss: 58.461217 - val_accuracy: 0.475000
# Epoch 160/500 - loss: 508.464059 - accuracy: 0.512500 - val_loss: 58.331682 - val_accuracy: 0.475000
# Epoch 170/500 - loss: 507.343914 - accuracy: 0.513889 - val_loss: 58.206521 - val_accuracy: 0.475000
# Epoch 180/500 - loss: 506.261951 - accuracy: 0.513889 - val_loss: 58.085450 - val_accuracy: 0.475000
# Epoch 190/500 - loss: 505.215957 - accuracy: 0.516667 - val_loss: 57.968210 - val_accuracy: 0.475000
# Epoch 200/500 - loss: 504.203826 - accuracy: 0.520833 - val_loss: 57.854557 - val_accuracy: 0.475000
# Epoch 210/500 - loss: 503.223559 - accuracy: 0.522222 - val_loss: 57.744260 - val_accuracy: 0.475000
# Epoch 220/500 - loss: 502.273257 - accuracy: 0.525000 - val_loss: 57.637106 - val_accuracy: 0.475000
# Epoch 230/500 - loss: 501.351114 - accuracy: 0.527778 - val_loss: 57.532892 - val_accuracy: 0.475000
# Epoch 240/500 - loss: 500.455415 - accuracy: 0.530556 - val_loss: 57.431429 - val_accuracy: 0.475000
# Epoch 250/500 - loss: 499.584529 - accuracy: 0.534722 - val_loss: 57.332537 - val_accuracy: 0.475000
# Epoch 260/500 - loss: 498.736907 - accuracy: 0.537500 - val_loss: 57.236047 - val_accuracy: 0.475000
# Epoch 270/500 - loss: 497.911076 - accuracy: 0.544444 - val_loss: 57.141799 - val_accuracy: 0.475000
# Epoch 280/500 - loss: 497.105636 - accuracy: 0.548611 - val_loss: 57.049643 - val_accuracy: 0.475000
# Epoch 290/500 - loss: 496.319257 - accuracy: 0.555556 - val_loss: 56.959435 - val_accuracy: 0.487500
# Epoch 300/500 - loss: 495.550676 - accuracy: 0.556944 - val_loss: 56.871041 - val_accuracy: 0.500000
# Epoch 310/500 - loss: 494.798690 - accuracy: 0.568056 - val_loss: 56.784331 - val_accuracy: 0.512500
# Epoch 320/500 - loss: 494.062158 - accuracy: 0.575000 - val_loss: 56.699185 - val_accuracy: 0.512500
# Epoch 330/500 - loss: 493.339996 - accuracy: 0.581944 - val_loss: 56.615487 - val_accuracy: 0.525000
# Epoch 340/500 - loss: 492.631173 - accuracy: 0.587500 - val_loss: 56.533129 - val_accuracy: 0.537500
# Epoch 350/500 - loss: 491.934712 - accuracy: 0.594444 - val_loss: 56.452006 - val_accuracy: 0.537500
# Epoch 360/500 - loss: 491.249681 - accuracy: 0.604167 - val_loss: 56.372021 - val_accuracy: 0.550000
# Epoch 370/500 - loss: 490.575200 - accuracy: 0.605556 - val_loss: 56.293081 - val_accuracy: 0.550000
# Epoch 380/500 - loss: 489.910431 - accuracy: 0.613889 - val_loss: 56.215097 - val_accuracy: 0.550000
# Epoch 390/500 - loss: 489.254580 - accuracy: 0.623611 - val_loss: 56.137987 - val_accuracy: 0.562500
# Epoch 400/500 - loss: 488.606892 - accuracy: 0.623611 - val_loss: 56.061671 - val_accuracy: 0.575000
# Epoch 410/500 - loss: 487.966653 - accuracy: 0.622222 - val_loss: 55.986073 - val_accuracy: 0.562500
# Epoch 420/500 - loss: 487.333186 - accuracy: 0.634722 - val_loss: 55.911124 - val_accuracy: 0.550000
# Epoch 430/500 - loss: 486.705850 - accuracy: 0.648611 - val_loss: 55.836755 - val_accuracy: 0.550000
# Epoch 440/500 - loss: 486.084038 - accuracy: 0.652778 - val_loss: 55.762904 - val_accuracy: 0.562500
# Epoch 450/500 - loss: 485.467174 - accuracy: 0.655556 - val_loss: 55.689510 - val_accuracy: 0.562500
# Epoch 460/500 - loss: 484.854717 - accuracy: 0.655556 - val_loss: 55.616516 - val_accuracy: 0.562500
# Epoch 470/500 - loss: 484.246152 - accuracy: 0.662500 - val_loss: 55.543870 - val_accuracy: 0.562500
# Epoch 480/500 - loss: 483.640996 - accuracy: 0.669444 - val_loss: 55.471521 - val_accuracy: 0.562500
# Epoch 490/500 - loss: 483.038793 - accuracy: 0.676389 - val_loss: 55.399421 - val_accuracy: 0.575000
# Accuracy on the test set is  0.585

# %%
# COMPARISONS WITH THE STANDARD LIBRARY 
#                        myNerualNet      |    Standard Library
#                     ------------------------------------------
# Model 1 Accuracy:         0.96          |           0.94
# Model 2 Accuracy:         0.955         |           0.94
# Model 3 Accuracy:         0.585         |           0.94
#                                         |
# Model 1 Loss:             37.69         |           0.59
# Model 2 Loss:             108.31        |           0.59
# Model 3 Loss:             483.04        |           0.59
# Overall, I would say my ANN has comprobale performance to the standard library.
# I did try using the tanh and softmax for the standard library, but the performance
# decayed significantly (accuracy was around 0.55).

# %% [markdown]
# ## Reflection
# Write at least a paragraph answering these prompts: How did your own network perform? Is there any major differences between the implementations? Finally, reflecting on your experience implementing a learning algorithm for this assignment (Was it hard/easy/fun?, From which part did you learn the most?)!
#
# I think that my neural network performed quite well in comparison to the standard library, as the accuracies are similar (even higher), with reasonable losses. The biggest differences between implementations is that my nerual net used tanh and softmax for the activation functions, while the standard library used relu and softmax. I also used far less nodes in my implementation (8 hidden nodes in the best model vs 50 nodes in the standard model). I would say that I enjoyed this assignment more than others, as the code was pretty straightforward to write (mostly following equations), it just took a while to figure out the best way to implement certain functions. I did not enjoy debugging, as there were several bugs that arose from using very similar python functions (ie: np.sum() vs sum() gave me completely different results!). I definitely learned the most from implementing the fit method, as it tied all the different parts together.

# %% [markdown]
# ---
# # Get Help?
# In case you get stuck in any step in the process, you may find some useful information from:
#
#  * Consult my [lecture 13](https://docs.google.com/presentation/d/1otQfmMomWctLZKI3hHKAA4lLkbXFtagLaQov8gNh4LI/edit?usp=sharing) and [Colab Notebook 10](https://colab.research.google.com/drive/1x5biI3dP5YvvDEI0wapJcSgQNnATDzNe)
#  * Talk to the TA, they are available and there to help you during office hour.
#  * Come talk to me or email me <nn4pj@virginia.edu> with subject starting "CS4774 Assignment 4:...".
#
# Part of the codes used in this assignment is modified from Konstantinos Kitsios under the 3-Clause BSD License. Best of luck and have fun!
